# %%
import random
a = [random.randint(1,100) for range in xrange(1000)]

# %%
dico = {v: 90 - v for v in a}
print len([(v, 90 - v) for v in dico if dico[v] in dico])
[(v, 90 - v) for v in dico if dico[v] in dico]
# Out:
# 89
# [(1, 89),
#  (2, 88),
#  (3, 87),
#  (4, 86),
#  (5, 85),
#  (6, 84),
#  (7, 83),
#  (8, 82),
#  (9, 81),
#  (10, 80),
#  (11, 79),
#  (12, 78),
#  (13, 77),
#  (14, 76),
#  (15, 75),
#  (16, 74),
#  (17, 73),
#  (18, 72),
#  (19, 71),
#  (20, 70),
#  (21, 69),
#  (22, 68),
#  (23, 67),
#  (24, 66),
#  (25, 65),
#  (26, 64),
#  (27, 63),
#  (28, 62),
#  (29, 61),
#  (30, 60),
#  (31, 59),
#  (32, 58),
#  (33, 57),
#  (34, 56),
#  (35, 55),
#  (36, 54),
#  (37, 53),
#  (38, 52),
#  (39, 51),
#  (40, 50),
#  (41, 49),
#  (42, 48),
#  (43, 47),
#  (44, 46),
#  (45, 45),
#  (46, 44),
#  (47, 43),
#  (48, 42),
#  (49, 41),
#  (50, 40),
#  (51, 39),
#  (52, 38),
#  (53, 37),
#  (54, 36),
#  (55, 35),
#  (56, 34),
#  (57, 33),
#  (58, 32),
#  (59, 31),
#  (60, 30),
#  (61, 29),
#  (62, 28),
#  (63, 27),
#  (64, 26),
#  (65, 25),
#  (66, 24),
#  (67, 23),
#  (68, 22),
#  (69, 21),
#  (70, 20),
#  (71, 19),
#  (72, 18),
#  (73, 17),
#  (74, 16),
#  (75, 15),
#  (76, 14),
#  (77, 13),
# ...
