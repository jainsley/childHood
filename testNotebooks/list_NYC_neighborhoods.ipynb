# %%
import pickle
randomHood = pickle.load(open("NYC_neighborhood_random_points.p", "rb"))

# %%
randomHood.keys()
# Out:
# [u'Ozone Park',
#  u'Greenpoint',
#  u'Financial District',
#  u'Arlington',
#  u'Ferry Point Park',
#  u'Kensington',
#  u'West Village',
#  u"Bull's Head",
#  u'Ridgewood',
#  u'Dyker Heights',
#  u'Concourse',
#  u'Port Richmond',
#  u'Cobble Hill',
#  u'Inwood',
#  u'Bay Terrace',
#  u'Allerton',
#  u'Rossville',
#  u'Kingsbridge',
#  u'Holliswood',
#  u'Breezy Point',
#  u'Prospect-Lefferts Gardens',
#  u'Rockaway Beach',
#  u'Gramercy',
#  u'Washington Heights',
#  u'John F. Kennedy International Airport',
#  u'Fort Wadsworth',
#  u'Astoria',
#  u'Todt Hill',
#  u'Clinton Hill',
#  u'Roosevelt Island',
#  u'Coney Island',
#  u'Gravesend',
#  u'University Heights',
#  u'Port Morris',
#  u'Stapleton',
#  u'Williamsburg',
#  u'Chinatown',
#  u'Wakefield',
#  u'Corona',
#  u'Mount Eden',
#  u'East Elmhurst',
#  u'Downtown Brooklyn',
#  u'Cambria Heights',
#  u'Upper West Side',
#  u'Harlem',
#  u'Bay Ridge',
#  u'Cunningham Park',
#  u'Two Bridges',
#  u'Jamaica',
# ...

# %%
randomHood.keys()[130:136]
# Out:
# [u'Bronx Park',
#  u'Manhattan Beach',
#  u'Carroll Gardens',
#  u'Douglaston',
#  u'Huguenot',
#  u'Gerritsen Beach']
